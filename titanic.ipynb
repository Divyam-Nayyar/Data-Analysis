# %%
import pandas as pd

# %%
titanic=pd.read_excel("titanic3.xls",index_col="name")
titanic.shape
# Out:
# (1309, 13)

# %%
titanic.head()
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
#
#                                                      age  sibsp  parch  \
# name
# Allen, Miss. Elisabeth Walton                    29.0000      0      0
# Allison, Master. Hudson Trevor                    0.9167      1      2
# Allison, Miss. Helen Loraine                      2.0000      1      2
# Allison, Mr. Hudson Joshua Creighton             30.0000      1      2
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000      1      2
#
#                                                  ticket      fare    cabin  \
# ...

# %%
titanic.sort_index(inplace=True)
titanic
# Out:
#                                                pclass  survived     sex   age  \
# name
# Abbing, Mr. Anthony                                 3         0    male  42.0
# Abbott, Master. Eugene Joseph                       3         0    male  13.0
# Abbott, Mr. Rossmore Edward                         3         0    male  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)                    3         1  female  35.0
# Abelseth, Miss. Karen Marie                         3         1  female  16.0
# ...                                               ...       ...     ...   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female  24.0
# van Billiard, Master. James William                 3         0    male   NaN
# van Billiard, Master. Walter John                   3         0    male  11.5
# van Billiard, Mr. Austin Blyler                     3         0    male  40.5
# van Melkebeke, Mr. Philemon                         3         0    male   NaN
#
# ...

# %%
titanic.loc["Abbott, Mr. Rossmore Edward"]
# Out:
# pclass                         3
# survived                       0
# sex                         male
# age                         16.0
# sibsp                          1
# parch                          1
# ticket                 C.A. 2673
# fare                       20.25
# cabin                        NaN
# embarked                       S
# boat                         NaN
# body                       190.0
# home.dest    East Providence, RI
# Name: Abbott, Mr. Rossmore Edward, dtype: object

# %%
titanic.loc["Kelly, Mr. James"]
# Out:
#                   pclass  survived   sex   age  sibsp  parch  ticket    fare  \
# name
# Kelly, Mr. James       3         0  male  34.5      0      0  330911  7.8292
# Kelly, Mr. James       3         0  male  44.0      0      0  363592  8.0500
#
#                  cabin embarked boat  body home.dest
# name
# Kelly, Mr. James   NaN        Q  NaN  70.0       NaN
# Kelly, Mr. James   NaN        S  NaN   NaN       NaN

# %%
titanic.loc[["Abbott, Mr. Rossmore Edward","Kelly, Mr. James"],["fare","sex","cabin"]]
# Out:
#                                 fare   sex cabin
# name
# Abbott, Mr. Rossmore Edward  20.2500  male   NaN
# Kelly, Mr. James              7.8292  male   NaN
# Kelly, Mr. James              8.0500  male   NaN

# %%
titanic.loc[["Abbott, Mr. Rossmore Edward","Kelly, Mr. James"],"fare"]
# Out:
# name
# Abbott, Mr. Rossmore Edward    20.2500
# Kelly, Mr. James                7.8292
# Kelly, Mr. James                8.0500
# Name: fare, dtype: float64

# %%
titanic3=pd.read_excel('titanic3.xls',usecols=['name','sex','age','fare','pclass'])
titanic3
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age      fare
# 0     29.0000  211.3375
# 1      0.9167  151.5500
# 2      2.0000  151.5500
# 3     30.0000  151.5500
# ...

# %%
titanic3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pclass  1309 non-null   int64
#  1   name    1309 non-null   object
#  2   sex     1309 non-null   object
#  3   age     1046 non-null   float64
#  4   fare    1308 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 51.3+ KB

# %%
titanic3.iloc[0:6]
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5       1                              Anderson, Mr. Harry    male  48.0000
#
#        fare
# 0  211.3375
# 1  151.5500
# 2  151.5500
# 3  151.5500
# 4  151.5500
# 5   26.5500

# %%
titanic3.loc[0:6:2]
# Out:
#    pclass                                             name     sex   age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0
# 2       1                     Allison, Miss. Helen Loraine  female   2.0
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 6       1                Andrews, Miss. Kornelia Theodosia  female  63.0
#
#        fare
# 0  211.3375
# 2  151.5500
# 4  151.5500
# 6   77.9583

# %%
titanic3.iloc[[4,5,6],3]
# Out:
# 4    25.0
# 5    48.0
# 6    63.0
# Name: age, dtype: float64

# %%
titanic3.iloc[0,[0,1,2]]
# Out:
# pclass                                1
# name      Allen, Miss. Elisabeth Walton
# sex                              female
# Name: 0, dtype: object

# %%
titanic3[:,]
