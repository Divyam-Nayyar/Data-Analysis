# %%
import pandas as pd

# %%
cols=["name","age","pclass","sex","fare"]
titanic=pd.read_excel("titanic3.xls",usecols=cols,index_col="name")

# %%
titanic.columns
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'fare'], dtype='object')

# %%
titanic.columns=["class","name","Gender","Age","Ticket Price"]
titanic
# Out:
#       class                                             name  Gender      Age  \
# 0         1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1         1                   Allison, Master. Hudson Trevor    male   0.9167
# 2         1                     Allison, Miss. Helen Loraine  female   2.0000
# 3         1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4         1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# ...     ...                                              ...     ...      ...
# 1304      3                             Zabour, Miss. Hileni  female  14.5000
# 1305      3                            Zabour, Miss. Thamine  female      NaN
# 1306      3                        Zakarian, Mr. Mapriededer    male  26.5000
# 1307      3                              Zakarian, Mr. Ortin    male  27.0000
# 1308      3                               Zimmerman, Mr. Leo    male  29.0000
#
#       Ticket Price
# ...

# %%
titanic.rename(columns={"Ticket Price":"Bhada"},inplace=True)
titanic
# Out:
#       class                                             name  Gender      Age  \
# 0         1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1         1                   Allison, Master. Hudson Trevor    male   0.9167
# 2         1                     Allison, Miss. Helen Loraine  female   2.0000
# 3         1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4         1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# ...     ...                                              ...     ...      ...
# 1304      3                             Zabour, Miss. Hileni  female  14.5000
# 1305      3                            Zabour, Miss. Thamine  female      NaN
# 1306      3                        Zakarian, Mr. Mapriededer    male  26.5000
# 1307      3                              Zakarian, Mr. Ortin    male  27.0000
# 1308      3                               Zimmerman, Mr. Leo    male  29.0000
#
#          Bhada
# 0     211.3375
# ...

# %%
titanic.rename({"Allen, Miss. Elisabeth Walton":"First Passenger"})
# Out:
#                                                  pclass     sex      age  \
# name
# First Passenger                                       1  female  29.0000
# Allison, Master. Hudson Trevor                        1    male   0.9167
# Allison, Miss. Helen Loraine                          1  female   2.0000
# Allison, Mr. Hudson Joshua Creighton                  1    male  30.0000
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female  25.0000
# ...                                                 ...     ...      ...
# Zabour, Miss. Hileni                                  3  female  14.5000
# Zabour, Miss. Thamine                                 3  female      NaN
# Zakarian, Mr. Mapriededer                             3    male  26.5000
# Zakarian, Mr. Ortin                                   3    male  27.0000
# Zimmerman, Mr. Leo                                    3    male  29.0000
#
#                                                      fare
# name
# ...

# %%
titanic.index.name="Index"
titanic.columns.name="Column"
titanic
# Out:
# Column                                           pclass     sex      age  \
# Index
# Allen, Miss. Elisabeth Walton                         1  female  29.0000
# Allison, Master. Hudson Trevor                        1    male   0.9167
# Allison, Miss. Helen Loraine                          1  female   2.0000
# Allison, Mr. Hudson Joshua Creighton                  1    male  30.0000
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female  25.0000
# ...                                                 ...     ...      ...
# Zabour, Miss. Hileni                                  3  female  14.5000
# Zabour, Miss. Thamine                                 3  female      NaN
# Zakarian, Mr. Mapriededer                             3    male  26.5000
# Zakarian, Mr. Ortin                                   3    male  27.0000
# Zimmerman, Mr. Leo                                    3    male  29.0000
#
# Column                                               fare
# Index
# ...
